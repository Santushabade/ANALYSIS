# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\DELL\Downloads\Houseprice_by_City.csv")
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %%
data.head(10)
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
# 5     Owner                   0     0        3       BHK  1250.000000
# 6    Dealer                   0     0        3       BHK  1495.053957
# 7     Owner                   0     1        3       BHK  1181.012946
# 8    Dealer                   0     1        2       BHK  1040.000000
# 9     Owner                   0     1        2       BHK   879.120879
#
#    READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# 0              1       1  Bangalore  12.969910  77.597960
# 1              1       1     Mysore  12.274538  76.644605
# ...

# %%
 data.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# City                     9
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
data["City"].fillna(11,inplace=True)

# %%
data.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# City                     0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %% [markdown]
# # Q1. Find the owner & dealar whose target price below 60 lack but they should approval by RERA?

# %%
a=data.loc[((data["POSTED_BY"]=="Owner")|(data["POSTED_BY"]=="Dealer"))&(data["RERA"]==1)&(data["TARGET(PRICE_IN_LACS)"]<=60)]
a
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 7         Owner                   0     1        3       BHK  1181.012946
# 8        Dealer                   0     1        2       BHK  1040.000000
# 9         Owner                   0     1        2       BHK   879.120879
# 22       Dealer                   0     1        3       BHK  1310.147689
# 31       Dealer                   0     1        2       BHK   943.126608
# ...         ...                 ...   ...      ...       ...          ...
# 29404    Dealer                   0     1        2       BHK   942.269409
# 29407     Owner                   0     1        3       BHK  1463.679075
# 29416     Owner                   0     1        1       BHK   550.055005
# 29417    Dealer                   1     1        2       BHK   656.628376
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE       City  LONGITUDE   LATITUDE  \
# ...

# %%
a["POSTED_BY"].unique()
# Out:
# array(['Owner', 'Dealer'], dtype=object)

# %%
a["RERA"].unique()
# Out:
# array([1], dtype=int64)

# %%
b=a["TARGET(PRICE_IN_LACS)"].unique()
b
# Out:
# array([52.  , 41.6 , 36.  , 55.  , 33.  , 51.6 , 39.9 , 22.1 , 60.  ,
#        24.9 , 42.  , 50.  , 48.  , 38.  , 46.  , 11.  , 57.9 , 33.9 ,
#        30.  , 21.5 , 45.9 , 58.5 , 50.2 , 44.9 , 37.5 , 40.  , 23.  ,
#        49.  , 40.6 , 36.1 , 46.6 , 45.  , 43.  , 51.  , 26.3 , 48.9 ,
#        16.  , 19.1 , 37.  , 35.  , 55.5 , 49.6 , 29.5 , 48.4 , 23.5 ,
#        41.  , 33.7 , 59.5 , 33.5 , 44.  , 48.1 , 54.9 , 22.5 , 31.7 ,
#        30.6 , 32.  , 47.  , 53.  , 23.4 , 21.9 , 21.8 , 49.8 , 47.3 ,
#        23.9 , 41.5 , 26.5 , 17.3 , 47.2 , 58.  , 30.5 , 54.  , 20.  ,
#        34.  , 20.6 , 24.5 , 48.5 , 57.4 , 56.  , 34.5 , 36.5 , 54.5 ,
#        29.  , 41.8 , 47.7 , 35.9 , 27.  , 57.  , 56.9 , 18.  , 46.9 ,
#        29.8 , 43.2 , 47.1 , 25.  , 26.  , 55.4 , 39.  , 54.7 , 18.5 ,
#        55.9 , 29.3 , 44.7 , 25.4 , 20.9 , 32.5 , 42.9 , 28.  , 56.6 ,
#        21.4 , 41.9 , 48.3 , 13.1 , 23.1 , 32.8 , 10.5 , 31.1 , 58.7 ,
# ...

# %%
a["TARGET(PRICE_IN_LACS)"].value_counts()
# Out:
# 60.00    107
# 55.00     95
# 45.00     95
# 50.00     75
# 35.00     72
#         ...
# 44.87      1
# 57.80      1
# 35.30      1
# 10.50      1
# 27.80      1
# Name: TARGET(PRICE_IN_LACS), Length: 456, dtype: int64

# %%
len(b)
# Out:
# 456

# %% [markdown]
# # Q2. Find 2BHK Owners but target price 60-90 and that should be ready to move?

# %%
d=data.loc[(((data["TARGET(PRICE_IN_LACS)"]>=60)&(data["TARGET(PRICE_IN_LACS)"]<=90)))&(data["POSTED_BY"]=="Owner")&(data["BHK_NO."]==2)&(data["READY_TO_MOVE"]==1)]

# %%
d
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 3         Owner                   0     1        2       BHK   929.921143
# 13        Owner                   0     1        2       BHK  1122.171946
# 56        Owner                   0     0        2       BHK   950.014616
# 68        Owner                   0     0        2       BHK  5000.000000
# 71        Owner                   0     0        2       BHK   760.070940
# ...         ...                 ...   ...      ...       ...          ...
# 29274     Owner                   0     1        2       BHK  1300.014445
# 29310     Owner                   0     0        2       BHK  1345.390384
# 29338     Owner                   0     0        2       BHK  1216.022890
# 29359     Owner                   0     0        2       BHK  1423.324151
# 29449     Owner                   0     0        2       BHK   927.079009
#
#        READY_TO_MOVE  RESALE        City  LONGITUDE   LATITUDE  \
# ...

# %% [markdown]
# # Q3. Find the Owners whose flat under counstruction  but these flat approve by RERA and show target price ?

# %%
e=data.loc[(data["POSTED_BY"]=="Owner")&(data["UNDER_CONSTRUCTION"]==1)&(data["RERA"]==1)]
e
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 100       Owner                   1     1        2       BHK   989.902989
# 122       Owner                   1     1        2       BHK  1109.165207
# 161       Owner                   1     1        4       BHK  2700.075602
# 684       Owner                   1     1        2       BHK  1069.937370
# 888       Owner                   1     1        3       BHK  1575.000000
# ...         ...                 ...   ...      ...       ...          ...
# 29202     Owner                   1     1        2       BHK   877.425044
# 29322     Owner                   1     1        2       BHK   990.099010
# 29326     Owner                   1     1        2       BHK  1114.126553
# 29360     Owner                   1     1        2       BHK  1090.159104
# 29436     Owner                   1     1        2       BHK  1175.132676
#
#        READY_TO_MOVE  RESALE        City  LONGITUDE   LATITUDE  \
# ...

# %%
e["POSTED_BY"].unique()
# Out:
# array(['Owner'], dtype=object)

# %%
e["UNDER_CONSTRUCTION"].unique()
# Out:
# array([1], dtype=int64)

# %%
e["RERA"].unique()
# Out:
# array([1], dtype=int64)

# %% [markdown]
# # Q4. Find Owners and dealers those flat size below 900 square foot and increase the target price by 5 lack?

# %%
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %%
f=data.loc[(data["POSTED_BY"]!="Builder")&(data["SQUARE_FT"]<=900)]
f
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK   SQUARE_FT  \
# 9         Owner                   0     1        2       BHK  879.120879
# 14        Owner                   0     0        1       BHK  649.983750
# 20        Owner                   0     0        2       BHK  881.143529
# 23       Dealer                   0     0        1       BHK  630.000630
# 25        Owner                   0     0        2       BHK  780.141844
# ...         ...                 ...   ...      ...       ...         ...
# 29431     Owner                   0     0        2       BHK  712.105799
# 29437    Dealer                   0     0        2       BHK  760.116253
# 29444    Dealer                   1     1        1       BHK  752.049334
# 29447     Owner                   0     0        2       BHK  769.230769
# 29450    Dealer                   0     1        2       BHK  896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %%
h=f["TARGET(PRICE_IN_LACS)"]+5
h
# Out:
# 9         41.0
# 14        25.0
# 20        50.0
# 23       305.0
# 25        32.5
#          ...
# 29431     26.0
# 29437     39.0
# 29444    105.0
# 29447     21.0
# 29450     32.8
# Name: TARGET(PRICE_IN_LACS), Length: 7086, dtype: float64

# %%
f["NewTarget"]=h
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10364\1388481910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f["NewTarget"]=h

# %%
f
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK   SQUARE_FT  \
# 9         Owner                   0     1        2       BHK  879.120879
# 14        Owner                   0     0        1       BHK  649.983750
# 20        Owner                   0     0        2       BHK  881.143529
# 23       Dealer                   0     0        1       BHK  630.000630
# 25        Owner                   0     0        2       BHK  780.141844
# ...         ...                 ...   ...      ...       ...         ...
# 29431     Owner                   0     0        2       BHK  712.105799
# 29437    Dealer                   0     0        2       BHK  760.116253
# 29444    Dealer                   1     1        1       BHK  752.049334
# 29447     Owner                   0     0        2       BHK  769.230769
# 29450    Dealer                   0     1        2       BHK  896.774194
#
#        READY_TO_MOVE  RESALE                  City  LONGITUDE   LATITUDE  \
# ...

# %% [markdown]
# # Q5. Find dealers those are having RERA approved and that flat size 2 BHK then decrease price by 2 lakh & above 2 BHK the increase price by 7 lakh ?

# %% [markdown]
# ### For  2 BHK decrease 2 in target price

# %%
j=data.loc[(data["POSTED_BY"]=="Dealer")&(data["RERA"]==1)&(data["BHK_NO."]==2)]
j
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 8        Dealer                   0     1        2       BHK  1040.000000
# 31       Dealer                   0     1        2       BHK   943.126608
# 34       Dealer                   0     1        2       BHK   857.786197
# 36       Dealer                   1     1        2       BHK  1020.087884
# 41       Dealer                   0     1        2       BHK  1058.114928
# ...         ...                 ...   ...      ...       ...          ...
# 29402    Dealer                   0     1        2       BHK  1015.977770
# 29404    Dealer                   0     1        2       BHK   942.269409
# 29417    Dealer                   1     1        2       BHK   656.628376
# 29439    Dealer                   1     1        2       BHK   975.609756
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE         City  LONGITUDE   LATITUDE  \
# ...

# %%
price2=[]
for x in j["TARGET(PRICE_IN_LACS)"]:
        k=x-2
        price2.append(k)
print(price2)
# Out:
# [39.6, 31.0, 238.0, 63.0, 63.0, 49.6, 68.0, 20.1, 79.5, 22.9, 40.0, 58.4, 46.0, 62.900000000000006, 44.0, 328.0, 178.0, 31.9, 108.0, 88.0, 138.0, 148.0, 138.0, 68.0, 19.5, 108.0, 43.9, 44.0, 118.0, 42.9, 158.0, 48.0, 63.5, 108.0, 89.0, 388.0, 368.0, 98.0, 38.6, 83.0, 34.1, 43.0, 41.0, 188.0, 49.0, 76.5, 74.5, 64.4, 148.0, 98.0, 228.0, 95.0, 68.0, 158.0, 128.0, 28.0, 76.0, 47.0, 53.5, 76.0, 44.0, 27.5, 46.4, 21.5, 128.0, 39.0, 98.0, 58.0, 298.0, 31.700000000000003, 66.4, 178.0, 118.0, 42.0, 46.1, 108.0, 63.0, 53.0, 20.5, 178.0, 29.7, 62.5, 38.0, 128.0, 50.0, 63.0, 72.5, 45.0, 118.0, 79.3, 63.0, 19.9, 98.0, 108.0, 58.0, 35.0, 19.8, 45.3, 21.9, 39.5, 93.0, 41.0, 47.0, 128.0, 108.0, 88.0, 79.0, 22.9, 88.0, 89.0, 56.0, 47.0, 52.0, 248.0, 18.6, 22.5, 54.0, 61.0, 73.0, 32.5, 60.0, 98.0, 52.5, 27.0, 148.0, 148.0, 31.0, 268.0, 39.8, 47.0, 45.7, 108.0, 138.0, 33.9, 168.0, 228.0, 41.0, 298.0, 76.0, 98.0, 158.0, 93.0, 56.0, 27.8, 128.0, 41.2, 108.0, 97.0, 45.1, 46.9, 108.0, 448.0, 158.0, 75.9, 5
# ...

# %%
j.insert(11,"NT",price2)

# %%
j
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 8        Dealer                   0     1        2       BHK  1040.000000
# 31       Dealer                   0     1        2       BHK   943.126608
# 34       Dealer                   0     1        2       BHK   857.786197
# 36       Dealer                   1     1        2       BHK  1020.087884
# 41       Dealer                   0     1        2       BHK  1058.114928
# ...         ...                 ...   ...      ...       ...          ...
# 29402    Dealer                   0     1        2       BHK  1015.977770
# 29404    Dealer                   0     1        2       BHK   942.269409
# 29417    Dealer                   1     1        2       BHK   656.628376
# 29439    Dealer                   1     1        2       BHK   975.609756
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE         City  LONGITUDE   LATITUDE     NT  \
# ...

# %% [markdown]
# ## for above 2 BHK Increase 7 in Target price

# %%
l=data.loc[(data["POSTED_BY"]=="Dealer")&(data["RERA"]==1)&(data["BHK_NO."]>2)]
l
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 15       Dealer                   1     1        3       BHK  1394.117647
# 17       Dealer                   1     1        3       BHK  2124.896706
# 19       Dealer                   0     1        3       BHK  2178.649237
# 22       Dealer                   0     1        3       BHK  1310.147689
# 43       Dealer                   0     1        3       BHK  1274.924779
# ...         ...                 ...   ...      ...       ...          ...
# 29386    Dealer                   0     1        3       BHK  1727.115717
# 29399    Dealer                   0     1        3       BHK  1850.149391
# 29409    Dealer                   0     1        4       BHK  5399.568035
# 29435    Dealer                   0     1        4       BHK  2189.160468
# 29443    Dealer                   0     1        3       BHK  1161.194975
#
#        READY_TO_MOVE  RESALE         City  LONGITUDE   LATITUDE  \
# ...

# %%
l["BHK_NO."].unique()
# Out:
# array([3, 4, 5, 6], dtype=int64)

# %%
price7=[]
for x in l["TARGET(PRICE_IN_LACS)"]:
    m=x+7
    price7.append(m)
print(price7)
# Out:
# [78.1, 187.0, 127.0, 62.0, 257.0, 78.9, 287.0, 217.0, 787.0, 107.0, 447.0, 147.0, 477.0, 247.0, 107.0, 307.0, 64.9, 106.0, 257.0, 117.0, 287.0, 86.5, 117.0, 167.0, 86.0, 407.0, 167.0, 107.0, 307.0, 227.0, 55.0, 57.2, 117.0, 187.0, 69.9, 44.5, 106.0, 177.0, 167.0, 477.0, 1207.0, 53.6, 357.0, 327.0, 74.0, 33.3, 177.0, 177.0, 757.0, 167.0, 70.0, 117.0, 257.0, 257.0, 307.0, 117.0, 85.0, 127.0, 42.0, 187.0, 94.0, 101.0, 247.0, 7287.0, 227.0, 104.6, 167.0, 79.0, 377.0, 117.0, 137.0, 207.0, 70.8, 1197.0, 357.0, 187.0, 90.0, 64.9, 77.0, 677.0, 66.5, 127.0, 107.0, 277.0, 61.9, 58.0, 94.5, 197.0, 187.0, 477.0, 37.6, 106.0, 100.0, 147.0, 397.0, 127.0, 60.0, 70.9, 127.0, 79.0, 147.0, 227.0, 557.0, 127.0, 56.8, 137.0, 72.2, 117.0, 54.2, 377.0, 107.0, 79.0, 102.9, 167.0, 67.0, 437.0, 9157.0, 55.5, 64.4, 147.0, 107.0, 76.0, 247.0, 54.3, 73.0, 207.0, 72.0, 47.0, 88.0, 187.0, 287.0, 51.0, 90.9, 104.6, 5167.0, 70.9, 237.0, 127.0, 83.1, 82.0, 317.0, 207.0, 107.0, 137.0, 53.9, 207.0, 107.0, 177.0, 52.0,
# ...

# %%
l.insert(11,"NT2",price7)
l
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 15       Dealer                   1     1        3       BHK  1394.117647
# 17       Dealer                   1     1        3       BHK  2124.896706
# 19       Dealer                   0     1        3       BHK  2178.649237
# 22       Dealer                   0     1        3       BHK  1310.147689
# 43       Dealer                   0     1        3       BHK  1274.924779
# ...         ...                 ...   ...      ...       ...          ...
# 29386    Dealer                   0     1        3       BHK  1727.115717
# 29399    Dealer                   0     1        3       BHK  1850.149391
# 29409    Dealer                   0     1        4       BHK  5399.568035
# 29435    Dealer                   0     1        4       BHK  2189.160468
# 29443    Dealer                   0     1        3       BHK  1161.194975
#
#        READY_TO_MOVE  RESALE         City  LONGITUDE   LATITUDE    NT2  \
# ...
